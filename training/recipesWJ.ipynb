# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('recipes.csv')

# Define a list of non-vegetarian keywords
non_vegetarian_keywords = ['meat', 'chicken', 'beef', 'pork', 'fish']

# Function to check if a RecipeIngredientParts is vegetarian
def is_vegetarian(ingredient):
    for keyword in non_vegetarian_keywords:
        if keyword in ingredient.lower():
            return False
    return True

# Apply the is_vegetarian function to the RecipeIngredientParts column
df['is_vegetarian'] = df['RecipeIngredientParts'].apply(is_vegetarian)

# Print the dataframe with the added is_vegetarian column
print(df)

df = pd.read_csv('recipes.csv')

# Get unique values from the RecipeIngredientParts column
unique_values = df['RecipeIngredientParts'].unique()

# Print the unique values
print(unique_values)

# count it
print(len(unique_values))
# Out:
#        RecipeId                                            Name  CookTime
# 0         73440                    Bow Ties With Broccoli Pesto         0  \
# 1        365718                             Cashew-chutney Rice      3600
# 2        141757        Copycat Taco Bell Nacho Fries BellGrande      3600
# 3        280351        Slow Cooker Jalapeno Cheddar Cheese Soup     18000
# 4        180505                 Cool & Crisp Citrus Chiffon Pie      3600
# ...         ...                                             ...       ...
# 75599    253577  Frijoles Negros- Crock Pot Mexican Black Beans     43200
# 75600    267827                                  Moose Moussaka      3600
# 75601    266983        Cantonese Pepper Steak for Two (Or More)      1800
# 75602    253739                            Coconut Cream Cooler       300
# 75603     78171                                 Cheater Risotto       960
#
#        PrepTime RecipeCategory
# 0          1800          Other  \
# 1           600          Other
# 2          2700          Other
# 3          1800          Other
# 4          1800          Other
# ...         ...            ...
# 75599     28800          Other
# 75600      2700          Other
# 75601       900          Other
# 75602       120          Other
# 75603       600          Other
#
#                               RecipeIngredientQuantities
# 0      c("\"6\"", "\"2\"", "\"1 1/2\"", "\"1/4\"", "\...  \
# 1      c("\"1\"", "\"3/4\"", "\"6\"", "\"5\"", "\"2\"...
# 2      c("\"3\"", "\"1/2\"", "\"1\"", "\"1\"", "\"3\"...
# 3      c("\"2\"", "\"1\"", "\"2\"", "\"2\"", "\"1\"",...
# 4      c("\"1\"", "\"1/4\"", "\"1/2\"", "\"1/2\"", "\...
# ...                                                  ...
# 75599  c("\"2\"", "\"6 -8\"", "\"5\"", "\"1/2\"", "\"...
# 75600  c("\"1\"", "\"6\"", "\"2\"", "\"2\"", "\"1/2\"...
# 75601  c("\"1/2\"", "\"1\"", "\"1/8\"", "\"1/8\"", "\...
# 75602  c("\"1\"", "\"1\"", "\"1\"", "\"7 1/2\"", "\"1...
# 75603  c("\"1\"", "\"3/4\"", "\"4\"", "\"1\"", "\"1\"...
#
#                                    RecipeIngredientParts  Calories
# 0      c("\"hazelnuts\"", "\"broccoli florets\"", "\"...     241.3  \
# 1      c("\"celery\"", "\"onion\"", "\"butter\"", "\"...     370.8
# 2      c("\"Copycat Taco Bell Seasoned Beef\"", "\"ye...     377.6
# 3      c("\"unsalted butter\"", "\"yellow onion\"", "...     282.8
# 4      c("\"unflavored gelatin\"", "\"water\"", "\"su...     257.5
# ...                                                  ...       ...
# 75599  c("\"black beans\"", "\"water\"", "\"bay leave...     121.5
# 75600  c("\"onion\"", "\"garlic cloves\"", "\"olive o...     652.2
# 75601  c("\"top round steak\"", "\"cornstarch\"", "\"...     223.9
# 75602             c("\"cream of coconut\"", "\"water\"")    2229.8
# 75603  c("\"arborio rice\"", "\"white wine\"", "\"gar...     654.1
#
#        FatContent  SaturatedFatContent  CholesterolContent  SodiumContent
# 0            10.1                  1.2                 0.0           13.1  \
# 1            17.5                  7.2                22.9          553.3
# 2            20.9                 10.5                45.7         1501.8
# 3            16.5                 10.3                50.5          630.2
# 4             8.6                  2.4               110.7          160.9
# ...           ...                  ...                 ...            ...
# 75599         0.5                  0.1                 0.0         1175.1
# 75600        25.8                 10.7               197.9          435.5
# 75601         9.2                  3.6                78.3          725.9
# 75602        80.3                 69.3                 0.0          294.7
# 75603        13.8                  6.9                34.6         1114.0
#
#        CarbohydrateContent  FiberContent  SugarContent  ProteinContent
# 0                     31.8           2.3           1.4             6.7  \
# 1                     44.3           1.6           2.2             9.4
# 2                     36.6           3.8           6.1            12.9
# 3                     22.8           2.3           2.7            11.7
# 4                     39.8           0.4          30.2             6.3
# ...                    ...           ...           ...             ...
# 75599                 22.2           7.8           0.6             7.9
# 75600                 51.9           7.5           7.2            50.1
# 75601                  7.3           1.1           1.7            26.7
# 75602                369.0          15.7         317.9            26.7
# 75603                 92.2           3.9           4.2            21.8
#
#        RecipeServings RecipeYield  is_vegetarian
# 0                 9.0         NaN           True
# 1                 8.0         NaN          False
# 2                 8.0         NaN          False
# 3                 6.0         NaN          False
# 4                 6.0         NaN           True
# ...               ...         ...            ...
# 75599             NaN         NaN           True
# 75600             NaN         NaN           True
# 75601             2.0         NaN           True
# 75602             NaN    1 gallon           True
# 75603             NaN  2 1/2 cups          False
#
# [75604 rows x 19 columns]
# ['c("\\"hazelnuts\\"", "\\"broccoli florets\\"", "\\"fresh parsley leaves\\"", "\\"olive oil\\"", "\\"mint leaf\\"", "\\"lemon juice\\"", "\\"lemon zest\\"", "\\"capers\\"", "\\"garlic cloves\\"", "\\"farfalle pasta\\"")'
#  'c("\\"celery\\"", "\\"onion\\"", "\\"butter\\"", "\\"chicken broth\\"", "\\"long grain rice\\"", "\\"unsalted cashews\\"", "\\"chutney\\"", "\\"salt\\"", "\\"pepper\\"")'
#  'c("\\"Copycat Taco Bell Seasoned Beef\\"", "\\"yellow onion\\"", "\\"green bell pepper\\"", "\\"garlic cloves\\"", "\\"ground cumin\\"", "\\"kosher salt\\"", "\\"whole black peppercorns\\"", "\\"tomato paste\\"", "\\"red wine vinegar\\"", "\\"cheddar cheese\\"", "\\"Velveeta cheese\\"", "\\"frozen french fries\\"", "\\"sweet paprika\\"", "\\"chili powder\\"", "\\"kosher salt\\"", "\\"cumin\\"", "\\"garlic powder\\"", "\\"sour cream\\"", "\\"tomatoes\\"")'
#  ...
#  'c("\\"top round steak\\"", "\\"cornstarch\\"", "\\"ground ginger\\"", "\\"garlic powder\\"", "\\"soy sauce\\"", "\\"green bell pepper\\"")'
#  'c("\\"cream of coconut\\"", "\\"water\\"")'
#  'c("\\"arborio rice\\"", "\\"white wine\\"", "\\"garlic cloves\\"", "\\"onion\\"", "\\"shallot\\"", "\\"butter\\"", "\\"olive oil\\"", "\\"chicken broth\\"", "\\"romano cheese\\"")']
# 73920
